# %%
import requests
import pandas as pd
import numpy as np
import re
import os

# %%
codigos_indicadores = {
	'Access_to_electricity_media': 'EG.ELC.ACCS.ZS',
	'AFFVA_media': 'NV.AGR.TOTL.ZS',
	"Agricultural_land_media" : "AG.LND.AGRI.ZS",
	"Cause_of_death_by_media" : "SH.DTH.COMM.ZS",
	'Control_of_Corruption_media': 'CC.EST',
	'Health_expenditure_per_capita_media': 'SH.XPD.CHEX.PC.CD',
	'Expenditure_on_education_media': 'SE.XPD.TOTL.GD.ZS',
	'GDP_per_capita_media': 'NY.GDP.PCAP.CD',
	"GDP_per_capita_growth_media" : "NY.GDP.PCAP.KD.ZG",
	"Food_insecurity_media" : "SN.ITK.SVFI.ZS",
	"Prevalence_of_undernourishment_media" : "SN.ITK.DEFC.ZS",
	'population_media': 'SP.POP.TOTL',
	'surface_area_media': 'AG.SRF.TOTL.K2',
	"Vulnerable_employment_media" : "SL.EMP.VULN.ZS",
	"Research_dev_expenditure_media" : "GB.XPD.RSDV.GD.ZS",
	"Primary_completion_rate_media" : "SE.PRM.CMPT.ZS"
}
codigos_indicadores = dict(sorted(codigos_indicadores.items()))
codigos_indicadores
# Out:
# {'AFFVA_media': 'NV.AGR.TOTL.ZS',
#  'Access_to_electricity_media': 'EG.ELC.ACCS.ZS',
#  'Agricultural_land_media': 'AG.LND.AGRI.ZS',
#  'Cause_of_death_by_media': 'SH.DTH.COMM.ZS',
#  'Control_of_Corruption_media': 'CC.EST',
#  'Expenditure_on_education_media': 'SE.XPD.TOTL.GD.ZS',
#  'Food_insecurity_media': 'SN.ITK.SVFI.ZS',
#  'GDP_per_capita_growth_media': 'NY.GDP.PCAP.KD.ZG',
#  'GDP_per_capita_media': 'NY.GDP.PCAP.CD',
#  'Health_expenditure_per_capita_media': 'SH.XPD.CHEX.PC.CD',
#  'Prevalence_of_undernourishment_media': 'SN.ITK.DEFC.ZS',
#  'Primary_completion_rate_media': 'SE.PRM.CMPT.ZS',
#  'Research_dev_expenditure_media': 'GB.XPD.RSDV.GD.ZS',
#  'Vulnerable_employment_media': 'SL.EMP.VULN.ZS',
#  'population_media': 'SP.POP.TOTL',
#  'surface_area_media': 'AG.SRF.TOTL.K2'}

# %%
class WBGData:
	def __init__(self):
		self._base_url = "https://api.worldbank.org/v2"
		self._params = {
			"format" : "json",
			"per_page" : 500,
			"page" : 1
		}

		self._data = dict()

	def get_indicator(self, indicator_code, pandas=True, pandas_format_long=True, params={}):
		endpoint = f"country/all/indicator/{indicator_code}"

		df = self._process_data(endpoint, params=params, pandas=pandas)

		if pandas_format_long or not pandas:
			return df
		else:
			return WBGData.dar_formato_indicador(df)

	def get_metadata(self, data, pandas=True, params={}):
		endpoint = f"{data}/all"

		return self._process_data(endpoint, params=params, pandas=pandas, type_="metadata")

	def get_metadata_of_indicator(self, code, pandas=True, params={}):
		endpoint = f"indicator/{code}"

		return self._process_data(endpoint, params=params, pandas=pandas, type_="metadata")


	def _process_data(self, endpoint, pandas=True, type_="indicator", params={}):
		self._get(endpoint, params=params)

		if pandas:
			df = pd.json_normalize(self._data, sep="_")
			df = df.replace("", np.nan)

			if type_ == "indicator":
				df = df.sort_values(by=["countryiso3code"]).reset_index(drop=True)
			elif "topics" in df.columns and type_ == "metadata":
				df[["topics_id", "topics_value"]] = df.apply(WBGData.tratar_columna_topics, axis=1)
				df = df.drop(columns=["topics"])

			return df
		else:
			return self._data

	def _get(self, endpoint, params={}):
		self._params["page"] = 1
		self._params.update(params)
		full_url = f"{self._base_url}/{endpoint}"

		all_data = []

		while True:
			response = requests.get(full_url, self._params)
			data = response.json()

			metadata = data[0]
			if "message" in metadata:
				raise KeyError(metadata["message"])

			pages = metadata["pages"]

			a_page = data[1]

			all_data.extend(a_page.copy())

			self._params["page"] += 1

			if self._params["page"] > pages:
				break

		self._data = all_data

	@staticmethod
	def tratar_columna_topics(series):
		topics = series.topics

		if not topics:
			return pd.Series([np.nan, np.nan])

		id = []
		value = []
		for t in topics:
			for key,v in t.items():
				if key == "id":
					id.append(v)
				elif key == "value":
					value.append(v)

		id = ", ".join(id)
		value = " & ".join(value)

		return pd.Series([id, value])

	@staticmethod
	def dar_formato_indicador(dataframe):
		df = dataframe.copy()

		# rellenar valores nulos en countryiso3code de forma temporal

		map_iso_null = {row :f"iso{index + 1}" for index,row in enumerate(df[df["countryiso3code"].isna()]["country_value"].unique())}
		df["countryiso3code"] = df.apply(lambda x: map_iso_null[x["country_value"]] if pd.isna(x["countryiso3code"]) else x["countryiso3code"],
										axis=1)

		# Pivotear valores de indicadores

		df_valores = df.pivot(index="countryiso3code", columns="date", values="value")
		df_valores = df_valores.reset_index()
		df_valores.columns.name = None

		# Acomodar otros los otros parametros

		df = df[['country_value','countryiso3code','indicator_value','indicator_id']].drop_duplicates()
		df = df.reset_index(drop=True)

		# Unir ambos dataframes

		df_salida = df.merge(df_valores, how="inner", on="countryiso3code")
		df_salida = df_salida.rename(columns={
			'country_value' : "Country Name",
			'countryiso3code' : "Country Code",
			'indicator_value': "Indicator Name",
			'indicator_id' : "Indicator Code"
		})

		# Eliminar valores nulos temporales en countryiso3code, ahora Country Code

		df_salida["Country Code"] = df_salida.apply(lambda x: np.nan if re.match(r"iso\d+", x["Country Code"]) else x["Country Code"], axis=1)

		return df_salida

# %%
metadata = pd.DataFrame(columns=["Indicador",
		"codigo_indicador",
		"anio_inicio",
		"anio_final"])

def trata_csv(dataset, indicador, first=False, skiprows=0):
	if isinstance(dataset, pd.DataFrame):
		dataframe = dataset.copy()
	elif os.path.isfile(dataset):
		dataframe = pd.read_csv(dataset, skiprows=skiprows)
	else:
		return

	dataframe = dataframe.dropna(how="all", axis=1)
	columns = dataframe.columns[dataframe.apply(lambda col: col.dtype == "float64")]
	dataframe[indicador] = dataframe[columns].dropna(how="all").mean(axis=1)

	max_ = max(columns, key=lambda x: int(x))
	min_ = min(columns, key=lambda x: int(x))

	metadata.loc[len(metadata)] = {
		"Indicador" : indicador,
		"codigo_indicador" : dataframe.iloc[1]["Indicator Code"],
		"anio_inicio" : min_,
		"anio_final" : max_
	}

	if not first:
		dataframe = dataframe[["Country Code", indicador]]
		dataframe = dataframe.rename(columns={"Country Code" : "Country_Code"})
	else:
		dataframe = dataframe[['Country Name', "Country Code", indicador]]
		dataframe = dataframe.rename(columns={'Country Name' : 'Country_Name', "Country Code" : "Country_Code"})

	return dataframe

# %%
wbg = WBGData()

# %%
def extraer_indicadores():
	global metadata
	df = pd.DataFrame()
	max_space = max([len(i) for i in codigos_indicadores.keys()]) + 2
	df_metadata = pd.DataFrame()

	for nombre,codigo in codigos_indicadores.items():
		print(f"Extrayendo indicador: {nombre:>{max_space}}", end="\r")
		dataset = wbg.get_indicator(codigo, pandas_format_long=False)
		df_metadata_indicator = wbg.get_metadata_of_indicator(codigo)
		df_metadata = pd.concat([df_metadata, df_metadata_indicator], ignore_index=True)
		df_indicador = trata_csv(dataset, nombre, skiprows=4)
		df_indicador = df_indicador.dropna(subset=["Country_Code"])
		try:
			df = df.merge(df_indicador, how="inner", on="Country_Code")
		except KeyError:
			df = df_indicador.copy()

	print("Completado!!")
	metadata = metadata.merge(df_metadata, how="left", left_on="codigo_indicador", right_on="id")
	metadata = metadata.drop(columns="id")
	return df

df = extraer_indicadores()
df
# Out:
# Completado!!ndicador:                     surface_area_media
#     Country_Code  AFFVA_media  Access_to_electricity_media  \
# 0            ABW     0.103728                    99.472445
# 1            AFE    13.177775                    31.756021
# 2            AFG    27.952003                    57.091304
# 3            AFW    22.446226                    41.742255
# 4            AGO     7.883305                    36.286957
# ..           ...          ...                          ...
# 256          XKX     7.986133                   100.000000
# 257          YEM    18.149629                    57.514358
# 258          ZAF     4.320056                    80.067227
# 259          ZMB    12.357125                    25.470565
# 260          ZWE    14.691535                    37.973419
#
#      Agricultural_land_media  Cause_of_death_by_media  \
# 0                  11.111111                      NaN
# 1                  43.959595                57.032263
# 2                  58.200348                45.071499
# 3                  35.758280                64.447321
# 4                  36.018630                65.045936
# ..                       ...                      ...
# 256                      NaN                      NaN
# 257                44.513458                37.310949
# 258                79.346281                42.427386
# 259                28.870820                63.128580
# 260                35.601718                59.878604
#
#      Control_of_Corruption_media  Expenditure_on_education_media  \
# 0                       1.139387                        5.325764
# 1                            NaN                        4.410762
# 2                      -1.420090                        2.956045
# 3                            NaN                        2.843056
# 4                      -1.233098                        3.034522
# ..                           ...                             ...
# 256                    -0.444194                             NaN
# 257                    -1.245655                        6.097335
# 258                     0.130031                        5.182884
# 259                    -0.564180                        3.718272
# 260                    -1.231347                        8.806114
#
#      Food_insecurity_media  GDP_per_capita_growth_media  GDP_per_capita_media  \
# 0                      NaN                     2.308296          21735.275013
# 1                      NaN                     0.359678            822.978192
# 2                19.328571                     1.152146            416.667609
# 3                      NaN                     0.898172            881.552220
# 4                26.700000                    -0.167378           2133.920034
# ..                     ...                          ...                   ...
# 256                    NaN                     4.468208           4005.794796
# 257              11.485714                    -1.135928            903.833244
# 258               7.850000                     0.690067           3602.799975
# 259              27.057143                     0.274728            698.678735
# 260              33.471429                     0.561338            776.439309
#
#      Health_expenditure_per_capita_media  \
# 0                                    NaN
# 1                              82.340549
# 2                              49.495439
# 3                              54.887711
# 4                              82.931208
# ..                                   ...
# 256                                  NaN
# 257                            51.806669
# 258                           469.418586
# 259                            55.232332
# 260                            89.665293
#
#      Prevalence_of_undernourishment_media  Primary_completion_rate_media  \
# 0                                     NaN                      98.165097
# 1                               25.814769                      56.787163
# 2                               27.938095                      45.264939
# 3                               12.997012                      60.471626
# 4                               31.590476                      41.712434
# ..                                    ...                            ...
# 256                                   NaN                            NaN
# 257                             31.047619                      58.005581
# 258                              4.976190                      87.440464
# 259                             41.395238                      78.625864
# 260                             31.661905                      90.225713
#
#      Research_dev_expenditure_media  Vulnerable_employment_media  \
# 0                               NaN                          NaN
# 1                          0.619447                    73.757455
# 2                               NaN                    88.861321
# 3                          0.151699                    81.822756
# 4                          0.032290                    68.868918
# ..                              ...                          ...
# 256                             NaN                          NaN
# 257                             NaN                    44.339272
# 258                        0.700868                    20.514348
# 259                        0.051096                    78.755861
# 260                             NaN                    70.690443
#
#      population_media  surface_area_media
# 0        7.790650e+04        1.800000e+02
# 1        3.579699e+08        1.512053e+07
# 2        1.878244e+07        6.528600e+05
# 3        2.438662e+08        9.166270e+06
# 4        1.518896e+07        1.246700e+06
# ..                ...                 ...
# 256      1.664839e+06                 NaN
# 257      1.612413e+07        5.279700e+05
# 258      3.894634e+07        1.219090e+06
# 259      9.235383e+06        7.526100e+05
# 260      9.776680e+06        3.907600e+05
#
# [261 rows x 17 columns]

# %%
df_geografic = wbg.get_metadata("country")[["id", "longitude", "latitude"]]
df_geografic = df_geografic.rename(columns={"id" : "Country_Code"})
df = df_geografic.merge(df, how="left", on="Country_Code")
df
# Out:
#     Country_Code longitude  latitude  AFFVA_media  \
# 0            ABW  -70.0167   12.5167     0.103728
# 1            AFE       NaN       NaN    13.177775
# 2            AFG   69.1761   34.5228    27.952003
# 3            AFR       NaN       NaN          NaN
# 4            AFW       NaN       NaN    22.446226
# ..           ...       ...       ...          ...
# 291          XZN       NaN       NaN          NaN
# 292          YEM   44.2075    15.352    18.149629
# 293          ZAF   28.1871   -25.746     4.320056
# 294          ZMB   28.2937  -15.3982    12.357125
# 295          ZWE   31.0672  -17.8312    14.691535
#
#      Access_to_electricity_media  Agricultural_land_media  \
# 0                      99.472445                11.111111
# 1                      31.756021                43.959595
# 2                      57.091304                58.200348
# 3                            NaN                      NaN
# 4                      41.742255                35.758280
# ..                           ...                      ...
# 291                          NaN                      NaN
# 292                    57.514358                44.513458
# 293                    80.067227                79.346281
# 294                    25.470565                28.870820
# 295                    37.973419                35.601718
#
#      Cause_of_death_by_media  Control_of_Corruption_media  \
# 0                        NaN                     1.139387
# 1                  57.032263                          NaN
# 2                  45.071499                    -1.420090
# 3                        NaN                          NaN
# 4                  64.447321                          NaN
# ..                       ...                          ...
# 291                      NaN                          NaN
# 292                37.310949                    -1.245655
# 293                42.427386                     0.130031
# 294                63.128580                    -0.564180
# 295                59.878604                    -1.231347
#
#      Expenditure_on_education_media  Food_insecurity_media  \
# 0                          5.325764                    NaN
# 1                          4.410762                    NaN
# 2                          2.956045              19.328571
# 3                               NaN                    NaN
# 4                          2.843056                    NaN
# ..                              ...                    ...
# 291                             NaN                    NaN
# 292                        6.097335              11.485714
# 293                        5.182884               7.850000
# 294                        3.718272              27.057143
# 295                        8.806114              33.471429
#
#      GDP_per_capita_growth_media  GDP_per_capita_media  \
# 0                       2.308296          21735.275013
# 1                       0.359678            822.978192
# 2                       1.152146            416.667609
# 3                            NaN                   NaN
# 4                       0.898172            881.552220
# ..                           ...                   ...
# 291                          NaN                   NaN
# 292                    -1.135928            903.833244
# 293                     0.690067           3602.799975
# 294                     0.274728            698.678735
# 295                     0.561338            776.439309
#
#      Health_expenditure_per_capita_media  \
# 0                                    NaN
# 1                              82.340549
# 2                              49.495439
# 3                                    NaN
# 4                              54.887711
# ..                                   ...
# 291                                  NaN
# 292                            51.806669
# 293                           469.418586
# 294                            55.232332
# 295                            89.665293
#
#      Prevalence_of_undernourishment_media  Primary_completion_rate_media  \
# 0                                     NaN                      98.165097
# 1                               25.814769                      56.787163
# 2                               27.938095                      45.264939
# 3                                     NaN                            NaN
# 4                               12.997012                      60.471626
# ..                                    ...                            ...
# 291                                   NaN                            NaN
# 292                             31.047619                      58.005581
# 293                              4.976190                      87.440464
# 294                             41.395238                      78.625864
# 295                             31.661905                      90.225713
#
#      Research_dev_expenditure_media  Vulnerable_employment_media  \
# 0                               NaN                          NaN
# 1                          0.619447                    73.757455
# 2                               NaN                    88.861321
# 3                               NaN                          NaN
# 4                          0.151699                    81.822756
# ..                              ...                          ...
# 291                             NaN                          NaN
# 292                             NaN                    44.339272
# 293                        0.700868                    20.514348
# 294                        0.051096                    78.755861
# 295                             NaN                    70.690443
#
#      population_media  surface_area_media
# 0        7.790650e+04        1.800000e+02
# 1        3.579699e+08        1.512053e+07
# 2        1.878244e+07        6.528600e+05
# 3                 NaN                 NaN
# 4        2.438662e+08        9.166270e+06
# ..                ...                 ...
# 291               NaN                 NaN
# 292      1.612413e+07        5.279700e+05
# 293      3.894634e+07        1.219090e+06
# 294      9.235383e+06        7.526100e+05
# 295      9.776680e+06        3.907600e+05
#
# [296 rows x 19 columns]

# %%
# datos de paises

def tratar_columnas(col):
	col = re.sub(r"\s", "_", col)

	while "__" in col:
		col = col.replace("__", "_")

	return col

df_datos = pd.read_csv("data/WBG_data/WDICountry.csv")
df_datos.columns = [tratar_columnas(col) for col in df_datos.columns]
df_datos = df_datos[
	['Country_Code', 'Short_Name', 'Table_Name', 'Long_Name', '2-alpha_code',
       'Currency_Unit', 'Region', 'WB-2_code']
]

df_datos
# Out:
#     Country_Code                   Short_Name                   Table_Name  \
# 0            ABW                        Aruba                        Aruba
# 1            AFE  Africa Eastern and Southern  Africa Eastern and Southern
# 2            AFG                  Afghanistan                  Afghanistan
# 3            AFW   Africa Western and Central   Africa Western and Central
# 4            AGO                       Angola                       Angola
# ..           ...                          ...                          ...
# 260          XKX                       Kosovo                       Kosovo
# 261          YEM                        Yemen                  Yemen, Rep.
# 262          ZAF                 South Africa                 South Africa
# 263          ZMB                       Zambia                       Zambia
# 264          ZWE                     Zimbabwe                     Zimbabwe
#
#                         Long_Name 2-alpha_code       Currency_Unit  \
# 0                           Aruba           AW       Aruban florin
# 1     Africa Eastern and Southern           ZH                 NaN
# 2    Islamic State of Afghanistan           AF      Afghan afghani
# 3      Africa Western and Central           ZI                 NaN
# 4     People's Republic of Angola           AO      Angolan kwanza
# ..                            ...          ...                 ...
# 260            Republic of Kosovo           XK                Euro
# 261             Republic of Yemen           YE         Yemeni rial
# 262      Republic of South Africa           ZA  South African rand
# 263            Republic of Zambia           ZM  New Zambian kwacha
# 264          Republic of Zimbabwe           ZW   Zimbabwean Dollar
#
#                          Region WB-2_code
# 0     Latin America & Caribbean        AW
# 1                           NaN        ZH
# 2                    South Asia        AF
# 3                           NaN        ZI
# 4            Sub-Saharan Africa        AO
# ..                          ...       ...
# 260       Europe & Central Asia        XK
# 261  Middle East & North Africa        RY
# 262          Sub-Saharan Africa        ZA
# 263          Sub-Saharan Africa        ZM
# 264          Sub-Saharan Africa        ZW
#
# [265 rows x 8 columns]

# %%
df = df_datos.merge(df, how="outer", on="Country_Code")
df = df[~df.Short_Name.isnull()]
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 265 entries, 0 to 264
# Data columns (total 26 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Country_Code                          265 non-null    object
#  1   Short_Name                            265 non-null    object
#  2   Table_Name                            265 non-null    object
#  3   Long_Name                             265 non-null    object
#  4   2-alpha_code                          263 non-null    object
#  5   Currency_Unit                         217 non-null    object
#  6   Region                                217 non-null    object
#  7   WB-2_code                             264 non-null    object
#  8   longitude                             211 non-null    object
#  9   latitude                              211 non-null    object
#  10  AFFVA_media                           249 non-null    float64
#  11  Access_to_electricity_media           260 non-null    float64
#  12  Agricultural_land_media               254 non-null    float64
#  13  Cause_of_death_by_media               227 non-null    float64
#  14  Control_of_Corruption_media           205 non-null    float64
#  15  Expenditure_on_education_media        243 non-null    float64
#  16  Food_insecurity_media                 163 non-null    float64
#  17  GDP_per_capita_growth_media           258 non-null    float64
#  18  GDP_per_capita_media                  258 non-null    float64
#  19  Health_expenditure_per_capita_media   234 non-null    float64
#  20  Prevalence_of_undernourishment_media  215 non-null    float64
#  21  Primary_completion_rate_media         248 non-null    float64
#  22  Research_dev_expenditure_media        187 non-null    float64
#  23  Vulnerable_employment_media           231 non-null    float64
#  24  population_media                      261 non-null    float64
#  25  surface_area_media                    260 non-null    float64
# dtypes: float64(16), object(10)
# memory usage: 55.9+ KB

# %%
df.to_csv("data/wbg_data.cvs", encoding="utf-8", index=False)

# %%
metadata = metadata.sort_values(by="Indicador")
metadata = metadata.reset_index(drop=True)
metadata
# Out:
#                                Indicador   codigo_indicador anio_inicio  \
# 0                            AFFVA_media     NV.AGR.TOTL.ZS        1960
# 1            Access_to_electricity_media     EG.ELC.ACCS.ZS        1990
# 2                Agricultural_land_media     AG.LND.AGRI.ZS        1961
# 3                Cause_of_death_by_media     SH.DTH.COMM.ZS        2000
# 4            Control_of_Corruption_media             CC.EST        1996
# 5         Expenditure_on_education_media  SE.XPD.TOTL.GD.ZS        1970
# 6                  Food_insecurity_media     SN.ITK.SVFI.ZS        2014
# 7            GDP_per_capita_growth_media  NY.GDP.PCAP.KD.ZG        1961
# 8                   GDP_per_capita_media     NY.GDP.PCAP.CD        1960
# 9    Health_expenditure_per_capita_media  SH.XPD.CHEX.PC.CD        2000
# 10  Prevalence_of_undernourishment_media     SN.ITK.DEFC.ZS        2001
# 11         Primary_completion_rate_media     SE.PRM.CMPT.ZS        1970
# 12        Research_dev_expenditure_media  GB.XPD.RSDV.GD.ZS        1996
# 13           Vulnerable_employment_media     SL.EMP.VULN.ZS        1991
# 14                      population_media        SP.POP.TOTL        1960
# 15                    surface_area_media     AG.SRF.TOTL.K2        1961
#
#    anio_final                                               name  unit  \
# 0        2023  Agriculture, forestry, and fishing, value adde...   NaN
# 1        2022            Access to electricity (% of population)   NaN
# 2        2021                 Agricultural land (% of land area)   NaN
# 3        2019  Cause of death, by communicable diseases and m...   NaN
# 4        2022                    Control of Corruption: Estimate   NaN
# 5        2023  Government expenditure on education, total (% ...   NaN
# 6        2021  Prevalence of severe food insecurity in the po...   NaN
# 7        2023                   GDP per capita growth (annual %)   NaN
# 8        2023                       GDP per capita (current US$)   NaN
# 9        2022  Current health expenditure per capita (current...   NaN
# 10       2021   Prevalence of undernourishment (% of population)   NaN
# 11       2023  Primary completion rate, total (% of relevant ...   NaN
# 12       2022    Research and development expenditure (% of GDP)   NaN
# 13       2022  Vulnerable employment, total (% of total emplo...   NaN
# 14       2023                                  Population, total   NaN
# 15       2021                              Surface area (sq. km)   NaN
#
#                                            sourceNote  \
# 0   Agriculture, forestry, and fishing corresponds...
# 1   Access to electricity is the percentage of pop...
# 2   Agricultural land refers to the share of land ...
# 3   Cause of death refers to the share of all deat...
# 4   Control of Corruption captures perceptions of ...
# 5   General government expenditure on education (c...
# 6   The percentage of people in the population who...
# 7   Annual percentage growth rate of GDP per capit...
# 8   GDP per capita is gross domestic product divid...
# 9   Current expenditures on health per capita in c...
# 10  Prevalence of undernourishments is the percent...
# 11  Primary completion rate, or gross intake ratio...
# 12  Gross domestic expenditures on research and de...
# 13  Vulnerable employment is contributing family w...
# 14  Total population is based on the de facto defi...
# 15  Surface area is a country's total area, includ...
#
#                                    sourceOrganization source_id  \
# 0   World Bank national accounts data, and OECD Na...         2
# 1   IEA, IRENA, UNSD, World Bank, WHO. 2023. Track...         2
# 2   Food and Agriculture Organization, electronic ...         2
# 3   Derived based on the data from Global Health E...         2
# 4   Detailed documentation of the WGI, interactive...         2
# 5   UNESCO Institute for Statistics (UIS). UIS.Sta...         2
# 6   Food and Agriculture Organization of the Unite...         2
# 7   World Bank national accounts data, and OECD Na...         2
# 8   World Bank national accounts data, and OECD Na...         2
# 9   World Health Organization Global Health Expend...         2
# 10  Food and Agriculture Organization (http://www....         2
# 11  UNESCO Institute for Statistics (UIS). UIS.Sta...         2
# 12  UNESCO Institute for Statistics (UIS). UIS.Sta...         2
# 13  World Bank, World Development Indicators datab...         2
# 14  (1) United Nations Population Division. World ...         2
# 15  Food and Agriculture Organization, electronic ...         2
#
#                     source_value topics_id  \
# 0   World Development Indicators  1, 3, 19
# 1   World Development Indicators  5, 19, 6
# 2   World Development Indicators  1, 19, 6
# 3   World Development Indicators         8
# 4   World Development Indicators        13
# 5   World Development Indicators         4
# 6   World Development Indicators         8
# 7   World Development Indicators         3
# 8   World Development Indicators         3
# 9   World Development Indicators         8
# 10  World Development Indicators         8
# 11  World Development Indicators  2, 19, 4
# 12  World Development Indicators        14
# 13  World Development Indicators     10, 2
# 14  World Development Indicators     19, 8
# 15  World Development Indicators      1, 6
#
#                                          topics_value
# 0   Agriculture & Rural Development   & Economy & ...
# 1    Energy & Mining  & Climate Change & Environment
# 2   Agriculture & Rural Development   & Climate Ch...
# 3                                             Health
# 4                                      Public Sector
# 5                                          Education
# 6                                             Health
# 7                                    Economy & Growth
# 8                                    Economy & Growth
# 9                                             Health
# 10                                            Health
# 11   Aid Effectiveness  & Climate Change & Education
# 12                              Science & Technology
# 13     Social Protection & Labor & Aid Effectiveness
# 14                           Climate Change & Health
# 15   Agriculture & Rural Development   & Environment

# %%
metadata.to_csv("data/WBG_data/indicators_metadata.csv", index=False, encoding="utf-8")
